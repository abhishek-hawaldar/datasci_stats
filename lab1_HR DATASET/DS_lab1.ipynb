# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishek-hawaldar/datasci_stats/blob/main/lab1_HR%20DATASET/DS_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Abhishek Hawaldar
#Roll No-21 TY-B-CS
#Data Science Assignment 1

import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/content/sample_data/HR.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Emp ID                  5000 non-null   int64
#  1   Name Prefix             5000 non-null   object
#  2   First Name              5000 non-null   object
#  3   Middle Initial          5000 non-null   object
#  4   Last Name               5000 non-null   object
#  5   Gender                  5000 non-null   object
#  6   E Mail                  5000 non-null   object
#  7   Father's Name           5000 non-null   object
#  8   Mother's Name           5000 non-null   object
#  9   Mother's Maiden Name    5000 non-null   object
#  10  Date of Birth           5000 non-null   object
#  11  Time of Birth           5000 non-null   object
#  12  Age in Yrs.             5000 non-null   float64
#  13  Weight in Kgs.          5000 non-null   int64
# ...

# %%
data.head()
# Out:
#    Emp ID Name Prefix First Name  ...     Region  User Name       Password
# 0  526540         Ms.  Angelique  ...  Northeast  akgoodwin     z{d>ez%{.@
# 1  859327         Ms.       Jeni  ...      South  jsshaffer       7U56!*!O
# 2  887387         Ms.     Donald  ...      South   dtfarris  rX.F{j&]&m&&X
# 3  779497        Hon.     Steven  ...    Midwest   sdrendon    a+2;sx}<G]y
# 4  896517        Drs.     Jenell  ...    Midwest  jlalmanza       Ou7RX{yT
#
# [5 rows x 37 columns]

# %%
print(data.columns)
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %%
data.sample(10)
# Out:
#       Emp ID Name Prefix First Name  ...     Region     User Name         Password
# 2203  232124         Ms.     Season  ...  Northeast        sishea       n|/d5vXfnG
# 2588  982637        Drs.     Chanel  ...      South     clharwell      m%iw8z6t~4h
# 1543  345306         Mr.     Daniel  ...    Midwest     dwhartman         z!Qwed++
# 2118  329371         Mr.    Wendell  ...      South     wmcardoza        wnG<GTvN]
# 366   811224         Mr.     Julius  ...       West  jywilliamson   DH2mzQ_%D{@DuX
# 3121  298308       Prof.    Jarrett  ...      South     jfshaffer  X>sl[ixX}6+#CLX
# 3820  482136         Ms.     George  ...      South       gewelsh        Z7u%H~IB@
# 2820  259459        Hon.        Yer  ...  Northeast     yupadgett   O{ACM-:hE_[hOS
# 2596  820896        Hon.   Latashia  ...       West       lndyson        Tn2L{GBYn
# 694   674758        Mrs.     Leonor  ...      South     lhcroteau       hM+WhpfBQo
#
# [10 rows x 37 columns]

# %%
print(data.shape)
# Out:
# (5000, 37)

# %%
data.values
# Out:
# array([[526540, 'Ms.', 'Angelique', ..., 'Northeast', 'akgoodwin',
#         'z{d>ez%{.@'],
#        [859327, 'Ms.', 'Jeni', ..., 'South', 'jsshaffer', '7U56!*!O'],
#        [887387, 'Ms.', 'Donald', ..., 'South', 'dtfarris',
#         'rX.F{j&]&m&&X'],
#        ...,
#        [313027, 'Mr.', 'Gerald', ..., 'Midwest', 'gjbeaudry', 'hAw[]_s-'],
#        [826852, 'Mrs.', 'Emilee', ..., 'Midwest', 'edemery',
#         'jj0uKCopdM'],
#        [948300, 'Ms.', 'Larhonda', ..., 'West', 'lgdozier', 'we_Uppg02']],
#       dtype=object)

# %%
data.agg(["mean","median"])
# Out:
#              Emp ID  Age in Yrs.  ...       Salary         Zip
# mean    555385.4624    40.497562  ...  119986.6148  50226.9642
# median  555986.0000    40.615000  ...  120234.0000  49379.5000
#
# [2 rows x 9 columns]

# %%
data.mean()
# Out:
# Emp ID                    555385.462400
# Age in Yrs.                   40.497562
# Weight in Kgs.                59.968200
# Year of Joining             2007.327400
# Month of Joining               6.345200
# Day of Joining                15.721400
# Age in Company (Years)         9.765914
# Salary                    119986.614800
# Zip                        50226.964200
# dtype: float64

# %%
data.median()
# Out:
# Emp ID                    555986.000
# Age in Yrs.                   40.615
# Weight in Kgs.                57.000
# Year of Joining             2010.000
# Month of Joining               6.000
# Day of Joining                16.000
# Age in Company (Years)         7.115
# Salary                    120234.000
# Zip                        49379.500
# dtype: float64

# %%
data.describe()
# Out:
#             Emp ID  Age in Yrs.  ...         Salary           Zip
# count    5000.0000  5000.000000  ...    5000.000000   5000.000000
# mean   555385.4624    40.497562  ...  119986.614800  50226.964200
# std    256301.1832    11.365336  ...   46434.151143  27579.386224
# min    111150.0000    21.010000  ...   40011.000000    211.000000
# 25%    335512.5000    30.690000  ...   79153.000000  27319.250000
# 50%    555986.0000    40.615000  ...  120234.000000  49379.500000
# 75%    781261.2500    50.382500  ...  160227.500000  73444.000000
# max    999800.0000    60.000000  ...  199968.000000  99919.000000
#
# [8 rows x 9 columns]

# %%
data.loc[:,["Emp ID"	,"Age in Yrs."]]
# Out:
#       Emp ID  Age in Yrs.
# 0     526540        53.24
# 1     859327        55.58
# 2     887387        59.34
# 3     779497        35.34
# 4     896517        59.12
# ...      ...          ...
# 4995  488800        23.07
# 4996  428330        47.40
# 4997  313027        35.29
# 4998  826852        50.15
# 4999  948300        30.57
#
# [5000 rows x 2 columns]

# %%
data.sort_values("Emp ID",ascending = True)
# Out:
#       Emp ID Name Prefix First Name  ...     Region    User Name        Password
# 3563  111150        Drs.   Sanjuana  ...    Midwest    sesaddler        9X86]CTj
# 4632  111500        Hon.    Jarrett  ...    Midwest      jmyanez     K|^5$R1@5bO
# 1431  111692         Dr.       Emil  ...       West     eqparris        y}axOm>z
# 3221  112574         Dr.    Raleigh  ...       West     roosorio    M6zTzQTaShxE
# 3157  112680         Mr.        Ira  ...      South     ivnathan     O|VC]y_3a/.
# ...      ...         ...        ...  ...        ...          ...             ...
# 652   998903        Mrs.    Chasity  ...    Midwest      chguido  b*4&3d8Aouc:D9
# 378   999307         Mr.      Daryl  ...      South  dctreadwell     8Wq?HZS[MhF
# 3666  999422        Hon.     Lorrie  ...  Northeast      lvbaber      r1C\~kk]Uu
# 4387  999496         Mr.      Bryan  ...      South      bxburks     8D9jX1-9R+^
# 4736  999800        Mrs.    Yolando  ...      South  ywstillwell    ht3-VRL-5|%{
#
# ...

# %%
data.filter(items["First Name", ])

# %%
data.groupby('Name Prefix').size()
# Out:
# Name Prefix
# Dr.       262
# Drs.      315
# Hon.      518
# Mr.      1779
# Mrs.      804
# Ms.      1078
# Prof.     244
# dtype: int64

# %%
data.groupby('Name Prefix').groups
# Out:
# {'Dr.': [17, 110, 112, 120, 123, 163, 165, 180, 191, 224, 242, 243, 253, 255, 257, 284, 309, 346, 354, 376, 380, 411, 418, 431, 432, 454, 460, 513, 530, 562, 564, 571, 608, 649, 669, 677, 678, 700, 719, 753, 759, 776, 812, 825, 868, 893, 900, 903, 904, 906, 928, 937, 940, 945, 968, 975, 987, 989, 991, 996, 1043, 1063, 1076, 1084, 1122, 1129, 1150, 1162, 1209, 1240, 1257, 1293, 1297, 1330, 1359, 1431, 1452, 1488, 1494, 1517, 1553, 1580, 1581, 1615, 1654, 1682, 1750, 1753, 1760, 1788, 1832, 1874, 1875, 1895, 1923, 1950, 1964, 2073, 2078, 2115, ...], 'Drs.': [4, 14, 65, 80, 83, 87, 115, 137, 160, 188, 196, 244, 245, 248, 264, 310, 315, 322, 385, 395, 419, 429, 439, 476, 503, 521, 528, 538, 566, 573, 581, 585, 587, 594, 597, 609, 621, 634, 665, 698, 704, 712, 732, 743, 818, 865, 866, 878, 887, 891, 932, 967, 984, 985, 1014, 1015, 1034, 1053, 1073, 1091, 1110, 1171, 1181, 1183, 1194, 1195, 1199, 1205, 1251, 1254, 1275, 1302, 1376, 1379, 1387, 1389, 1395, 1414, 1416, 1439, 1462, 1469, 1486
# ...

# %%
data.loc[:'Age in Yrs.']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bf66e8269b92> in <module>()
# ----> 1 data.loc[:'Age in Yrs.']
#
# NameError: name 'data' is not defined

# %%
data.groupby('Gender').agg(['min',"mean"])
# Out:
#         Emp ID                Age in Yrs.  ...         Salary   Zip
#            min           mean         min  ...           mean   min          mean
# Gender                                     ...
# F       111150  554167.774818       21.01  ...  119852.776836  1060  49869.226796
# M       111500  556581.905630       21.02  ...  120118.117764   211  50578.460349
#
# [2 rows x 18 columns]

# %%
data.iloc[-1] #last record
# Out:
# Emp ID                                     948300
# Name Prefix                                   Ms.
# First Name                               Larhonda
# Middle Initial                                  G
# Last Name                                  Dozier
# Gender                                          F
# E Mail                    larhonda.dozier@aol.com
# Father's Name                      Houston Dozier
# Mother's Name                         Gene Dozier
# Mother's Maiden Name                      Richard
# Date of Birth                            1/8/1987
# Time of Birth                         01:42:36 AM
# Age in Yrs.                                 30.57
# Weight in Kgs.                                 40
# Date of Joining                         4/25/2015
# Quarter of Joining                             Q2
# Half of Joining                                H1
# Year of Joining                              2015
# Month of Joining                                4
# ...

# %%
data.iloc[3:5]
# Out:
#    Emp ID Name Prefix First Name  ...   Region  User Name     Password
# 3  779497        Hon.     Steven  ...  Midwest   sdrendon  a+2;sx}<G]y
# 4  896517        Drs.     Jenell  ...  Midwest  jlalmanza     Ou7RX{yT
#
# [2 rows x 37 columns]

# %%
data.drop("Name Prefix",axis=1)
# Out:
#       Emp ID First Name Middle Initial  ...     Region  User Name         Password
# 0     526540  Angelique              K  ...  Northeast  akgoodwin       z{d>ez%{.@
# 1     859327       Jeni              S  ...      South  jsshaffer         7U56!*!O
# 2     887387     Donald              T  ...      South   dtfarris    rX.F{j&]&m&&X
# 3     779497     Steven              D  ...    Midwest   sdrendon      a+2;sx}<G]y
# 4     896517     Jenell              L  ...    Midwest  jlalmanza         Ou7RX{yT
# ...      ...        ...            ...  ...        ...        ...              ...
# 4995  488800    Roberto              R  ...  Northeast   rrharter         b>|V#Ywx
# 4996  428330    Brittni              B  ...      South      bbcyr  We/b$tUwvstNmE2
# 4997  313027     Gerald              J  ...    Midwest  gjbeaudry         hAw[]_s-
# 4998  826852     Emilee              D  ...    Midwest    edemery       jj0uKCopdM
# ...
