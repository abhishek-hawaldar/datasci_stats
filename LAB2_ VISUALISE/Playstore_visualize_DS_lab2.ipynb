# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishek-hawaldar/datasci_stats/blob/main/LAB2_%20VISUALISE/Playstore_visualize_DS_lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #                            PlayStore Analysis

# %%
#Abhishek Hawaldar
#Roll No-21 TY-B-CS
#Data Science Assignment 2


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('https://raw.githubusercontent.com/abhishek-hawaldar/datasci_stats/main/Processed__playstore_stats.csv')

# %%
df.shape
#We have got around 9369 apps to analyze for their ratings and performance.
# Out:
# (9360, 13)

# %%
df.head()
# Out:
#                                                  App  ... Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...         4.0
# 1                                Coloring book moana  ...         4.0
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...         4.0
# 3                              Sketch - Draw & Paint  ...         4.0
# 4              Pixel Draw - Number Art Coloring Book  ...         4.0
#
# [5 rows x 13 columns]

# %%
df.Reviews = df.Reviews.astype('int64') #Changing to int type.

# %%
df.shape
# Out:
# (9360, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9360 entries, 0 to 9359
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   int64
#  4   Size            9360 non-null   float64
#  5   Installs        9360 non-null   float64
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   float64
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 950.8+ KB

# %%
plt.figure(figsize=(12,5))
plt.ylabel('Price')
plt.xlabel('Rating')
plt.title('Price vs rating')
plt.scatter(df['Rating'], df['Price'] ,alpha=0.2)

# %%
plt.figure(figsize=(12,5))


plt.xlabel('Price')
plt.ylabel('Rating')
plt.title(' rating vs Price')
plt.bar( df['Price'], df['Rating'] )
# Out:
# <BarContainer object of 9360 artists>

# %%
plt.figure(figsize=(12,5))
plt.ylabel('Price')
plt.xlabel('installs')
plt.title('Price vs installs')
plt.scatter(df['Installs'], df['Price'] ,alpha=0.2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9360 entries, 0 to 9359
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   int64
#  4   Size            9360 non-null   float64
#  5   Installs        9360 non-null   float64
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   float64
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 950.8+ KB

# %% [markdown]
# ***

# %%
 #dataframe.loc[dataframe['Stream'].isin(options)] 
 
 
 sns.boxplot(x="Category", y="Rating", data=df.loc[df['Category'].isin(['GAME','FAMILY','TOOLS','PRODUCTIVITY' ]) ], hue='Type')

# %%
sns.set_style('darkgrid') 
  
sns.barplot(x ='Type', y ='Installs', data = df, palette ='plasma') 
# avg sal is same

# %%
sns.barplot(x ='Type', y ='Installs', data = df[df['Type']== 'Paid'])

# %%
sns.heatmap(df.corr(), annot=True, fmt='.2f')

# %%
#x=df[['Rating','Reviews','Size',]]
sns.pairplot(df)

# %%
plt.figure(figsize=(12,5))
sns.distplot(df['Installs'], color = 'Red', label = 'installs')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Rating'], color = 'Red', label = 'indyalld')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Reviews'], color = 'Red', label = 'indyalld')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Price'], color = 'Red', label = 'indyalld')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Size'], color = 'Red', label = 'indyalld')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.Rating[df['Rating'] == 5 ].count()
# Out:
# 274

# %%
df.Size[df['Size']>1].count()
# Out:
# 7719

# %%
df.Category.value_counts()
# Out:
# FAMILY                 1746
# GAME                   1097
# TOOLS                   733
# PRODUCTIVITY            351
# MEDICAL                 350
# COMMUNICATION           328
# FINANCE                 323
# SPORTS                  319
# PHOTOGRAPHY             317
# LIFESTYLE               314
# PERSONALIZATION         312
# BUSINESS                303
# HEALTH_AND_FITNESS      297
# SOCIAL                  259
# SHOPPING                238
# NEWS_AND_MAGAZINES      233
# TRAVEL_AND_LOCAL        226
# DATING                  195
# BOOKS_AND_REFERENCE     178
# VIDEO_PLAYERS           160
# EDUCATION               155
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     124
# FOOD_AND_DRINK          109
# HOUSE_AND_HOME           76
# WEATHER                  75
# AUTO_AND_VEHICLES        73
# LIBRARIES_AND_DEMO       64
# ART_AND_DESIGN           61
# COMICS                   58
# PARENTING                50
# EVENTS                   45
# BEAUTY                   42
# ...

# %%
df.Category.value_counts().plot(kind='barh',figsize= (12,8))

# Maximum Number of Apps belong to the Family and Game Category.

# %%
grp=df.groupby('Category').size()

# %%
x=df.groupby('Category').groups
a=list(x.keys())

# %%
plt.pie(grp , labels=a)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f309938e490>,
# ...
#  [Text(1.0997694552447252, 0.02251988700505552, 'ART_AND_DESIGN'),
#   Text(1.0976448155273815, 0.07194344268841218, 'AUTO_AND_VEHICLES'),
#   Text(1.094051022999124, 0.11424692151025476, 'BEAUTY'),
#   Text(1.0826413104020456, 0.19464786926894911, 'BOOKS_AND_REFERENCE'),
#   Text(1.0372748388548718, 0.3661432898177977, 'BUSINESS'),
#   Text(0.9854142209550733, 0.48883413663481645, 'COMICS'),
#   Text(0.9140007389891884, 0.6120479140779891, 'COMMUNICATION'),
#   Text(0.7930668674093915, 0.7622630410937257, 'DATING'),
#   Text(0.6982605923878896, 0.8499600844263885, 'EDUCATION'),
#   Text(0.6080539611465732, 0.916662631688432, 'ENTERTAINMENT'),
#   Text(0.5471197903746116, 0.9542850386443462, 'EVENTS'),
#   Text(-0.08851326202779988, 1.0964330360059378, 'FAMILY'),
#   Text(-0.7696824512839804, 0.7858682613424995, 'FINANCE'),
#   Text(-0.8751550732482745, 0.6664109826284434, 'FOOD_AND_DRINK'),
# ...

# %%
df.Rating.describe()
# Out:
# count    9360.000000
# mean        4.191838
# std         0.515263
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max         5.000000
# Name: Rating, dtype: float64

# %%
sns.distplot(df.Rating)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print("No. of Apps with full ratings: ",df.Rating[df['Rating'] == 5 ].count())
# Out:
# No. of Apps with full ratings:  274

# %%
sns.distplot(df.Reviews)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df[df.Reviews>40000000]
# Out:
#                                            App  ... Android Ver
# 322   Messenger – Text and Video Chat for Free  ...         0.0
# 323                         WhatsApp Messenger  ...         0.0
# 368                         WhatsApp Messenger  ...         0.0
# 369   Messenger – Text and Video Chat for Free  ...         0.0
# 1586                            Clash of Clans  ...         4.0
# 1620                            Clash of Clans  ...         4.0
# 1795                            Clash of Clans  ...         4.0
# 2403                                  Facebook  ...         0.0
# 2404                                 Instagram  ...         0.0
# 2463                                 Instagram  ...         0.0
# 2470                                 Instagram  ...         0.0
# 3750                        WhatsApp Messenger  ...         0.0
# 3755                                 Instagram  ...         0.0
# 3789                                  Facebook  ...         0.0
# ...

# %%
plt.pie(df.Type.value_counts(), labels=['Free', 'Paid'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f30992997d0>,
# ...
#  [Text(-1.074323658852023, 0.2362809260833427, 'Free'),
#   Text(1.0743236699131302, -0.23628087579062296, 'Paid')])

# %%
df[df.Price == df.Price.max()]
# Out:
#                            App   Category  ...  Current Ver  Android Ver
# 4194  I'm Rich - Trump Edition  LIFESTYLE  ...        1.0.1          4.0
#
# [1 rows x 13 columns]

# %%
df['Android Ver'].value_counts()
# Out:
# 4.0    5856
# 0.0    1319
# 2.0    1177
# 5.0     556
# 3.0     250
# 1.0     104
# 6.0      48
# 7.0      45
# 8.0       5
# Name: Android Ver, dtype: int64

# %%
sns.countplot(df['Android Ver'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_full = df[df.Rating == 5]

df_full.sample(10)
# Out:
#                                                     App  ... Android Ver
# 5792                                   Bh Public School  ...         4.0
# 8348                                   Hum Ek Hain 2.02  ...         5.0
# 5574                                       BC MVA Fines  ...         4.0
# 8016                                            DYPSOET  ...         4.0
# 7585                          Disciple Maker’s (DM) Lab  ...         4.0
# 4881                                   Eternal Light AG  ...         4.0
# 8991  FD Calculator (EMI, SIP, RD & Loan Eligilibility)  ...         4.0
# 6459                                            CB News  ...         4.0
# 8347                           Ek Bander Ne Kholi Dukan  ...         4.0
# 6633                            CJ'S TIRE AND AUTO INC.  ...         4.0
#
# [10 rows x 13 columns]

# %%
sns.distplot(df_full.Installs)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_full.Installs.value_counts().sort_index()
# Out:
# 1.0          3
# 5.0          8
# 10.0        48
# 50.0        32
# 100.0      114
# 500.0       27
# 1000.0      38
# 5000.0       3
# 10000.0      1
# Name: Installs, dtype: int64

# %%
sns.distplot(df_full.Reviews)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_full = df_full[df_full.Reviews > 30]
df_full
# Out:
#                                                     App  ... Android Ver
# 4923   AI Today : Artificial Intelligence News & AI 101  ...         4.0
# 4952                                             AJ Cam  ...         4.0
# 5476                             Quran Khmer Offline AY  ...         4.0
# 6234                     Barisal University App-BU Face  ...         4.0
# 6698                                            CL REPL  ...         4.0
# 6708                                        CL Notifier  ...         4.0
# 6988                        CS & IT Interview Questions  ...         4.0
# 7180                                         Oración CX  ...         4.0
# 7330   Superheroes, Marvel, DC, Comics, TV, Movies News  ...         5.0
# 8335                                         Master E.K  ...         4.0
# 8351                                            Ek Vote  ...         4.0
# 8991  FD Calculator (EMI, SIP, RD & Loan Eligilibility)  ...         4.0
# ...

# %%
print("No. of Apps having 5.0 Rating with sufficient Reviews: ",df_full.App.count())
# Out:
# No. of Apps having 5.0 Rating with sufficient Reviews:  16

# %%
plt.figure(figsize=(12,5))
sns.countplot(df_full.Genres)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df_full.Price)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
